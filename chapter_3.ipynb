# %% [markdown]
# # Chapter 3 - Paths Through Graphs

# %% [markdown]
# ## Paths

# %% [markdown]
# ## Path Representation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Note:** You can trace the path back to node `0`, regardless of whether you are at node `7` or node `6`.

# %%
reversed([6, 5, 3, 1, 0])

# %%
list(reversed([6, 5, 3, 1, 0]))
# Out:
# [0, 1, 3, 5, 6]

# %%
# Alt:
[6, 5, 3, 1, 0][::-1]
# Out:
# [0, 1, 3, 5, 6]

# %% [markdown]
# ## Calculating Path Cost

# %% [markdown]
# ## Reachability

# %% [markdown]
# ## Why This Matters
